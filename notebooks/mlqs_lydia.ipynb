# %% [markdown]
# <a href="https://colab.research.google.com/github/mrushad/ml4qs-G39/blob/main/notebooks/mlqs_lydia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # Cloning github repo to access data

# %%
# !git clone https://github.com/mrushad/ml4qs-G39
# Out:
# fatal: destination path 'ml4qs-G39' already exists and is not an empty directory.

# %% [markdown]
# # Functions

# %% [markdown]
# ## read_csv_files()

# %%
def read_csv_files():
  csv_files = [
      'Accelerometer.csv',
      'Linear Accelerometer.csv',
      'Barometer.csv',
      'Location.csv',
      'Gyroscope.csv',
      'Magnetometer.csv',
      'Proximity.csv'
  ]

  # Dictionary to store DataFrames
  dfs = {}

  for filename in csv_files:
      try:
          # Create a clean DataFrame name (e.g., 'Accelerometer_df')
          df_name = filename.replace('.csv', '') + '_df'

          # Read the CSV file
          df = pd.read_csv(filename)

          # Store it in the dictionary
          dfs[df_name] = df

          print(f"Loaded '{filename}' into DataFrame '{df_name}'. Shape: {df.shape}")
          # Optional: Display the first few rows to verify
          # print(dfs[df_name].head())

      except FileNotFoundError:
          print(f"Error: '{filename}' not found in the current directory ({os.getcwd()}).")
      except Exception as e:
          print(f"Error loading '{filename}': {e}")

  # --- Accessing your DataFrames ---

  # You can now access your DataFrames like this:
  if 'Accelerometer_df' in dfs:
      print("\nAccelerometer_df head:")
      print(dfs['Accelerometer_df'].head())

  if 'Gyroscope_df' in dfs:
      print("\nGyroscope_df head:")
      print(dfs['Gyroscope_df'].head())

  # Or iterate through them
  print("\n--- All loaded DataFrames ---")
  for name, df in dfs.items():
      print(f"DataFrame: {name}, Columns: {df.columns.tolist()}, Shape: {df.shape}")
  return dfs

# %% [markdown]
# ## combine_dfs()

# %%
def combine_dfs(sensor_dfs):
    # Initialize an empty list to store processed DataFrames
    processed_dfs = []

    # Process each DataFrame
    for sensor_name, df in sensor_dfs.items(): # Iterate using the 'sensor_dfs' for cleaner prefixes
        # Create a copy to avoid modifying the original DataFrame directly
        df_copy = df.copy()

        # Round the 'Time (s)' column to three decimal places
        df_copy['Time (s)'] = df_copy['Time (s)'].round(2)

        # Rename columns to include the sensor name as a prefix
        new_columns = {}
        for col in df_copy.columns:
            if col != 'Time (s)':
                # Replace spaces in column names with underscores for consistency
                # Also remove parentheses from the unit part of the column name
                new_col_name = f"{sensor_name}_{col.replace(' ', '_').replace('(', '').replace(')', '')}"
                new_columns[col] = new_col_name
        df_copy = df_copy.rename(columns=new_columns)
        processed_dfs.append(df_copy) # Correctly append to 'processed_dfs'

    # Merge all processed DataFrames based on the 'Time (s)' column
    # Start with the first processed DataFrame
    if processed_dfs:
        combined_df = processed_dfs[0] # Use 'processed_dfs' for merging
        for i in range(1, len(processed_dfs)):
            combined_df = pd.merge(combined_df, processed_dfs[i], on='Time (s)', how='outer')

        # Display the combined DataFrame information
        print("Combined DataFrame Head:")
        print(combined_df.head())
        print("\nCombined DataFrame Info:")
        combined_df.info()
    else:
        print("No DataFrames to combine.")
    return combined_df

# %% [markdown]
# ## identify_correlation()

# %%
def identify_correlation(df, correlation_method='spearman', correlation_threshold=0.6):

    correlation = biking_df.corr(method=correlation_method)
    correlation_threshold = 0.60

    print(f"Pairs with Strong Spearman Correlation (absolute value >= {correlation_threshold}):\n")
    num_cols = len(correlation.columns)
    found_strong_correlation = False

    for i in range(num_cols):
        for j in range(i + 1, num_cols):
            var1 = correlation.columns[i]
            var2 = correlation.columns[j]
            correlation_value = correlation.iloc[i, j]

            if abs(correlation_value) >= correlation_threshold:
                print(f"  {var1} vs {var2}: {correlation_value:.4f}")
                found_strong_correlation = True

    if not found_strong_correlation:
        print("  No pairs found with strong Spearman correlation above the threshold.")

# %% [markdown]
# # CSV to DF

# %% [markdown]
# ## Biking Data

# %%
os.chdir('ml4qs-G39')
# !ls -F
# Out:
# data/  LICENSE	notebooks/  README.md  reports/  requirements.txt  src/

# %%
# %cd data/raw
# Out:
# /content/ml4qs-G39/data/raw

# %%
# !ls -F
# Out:
# 'BikingData1 2025-06-06 10-48-07'/  'WalkingData1 2025-06-06 15-30-08'/

# %%
# %cd BikingData1 2025-06-06 10-48-07
# Out:
# /content/ml4qs-G39/data/raw/BikingData1 2025-06-06 10-48-07

# %%
# !ls -F
# Out:
#  Accelerometer.csv  'Linear Accelerometer.csv'	 meta/
#  Barometer.csv	     Location.csv		 Proximity.csv
#  Gyroscope.csv	     Magnetometer.csv

# %%
biking_dfs = read_csv_files()
bkining_accelerometer_df = biking_dfs['Accelerometer_df']
bkining_linear_accelerometer_df = biking_dfs['Linear Accelerometer_df']
bkining_barometer_df = biking_dfs['Barometer_df']
bkining_location_df = biking_dfs['Location_df']
bkining_gyroscope_df = biking_dfs['Gyroscope_df']
bkining_magnetometer_df = biking_dfs['Magnetometer_df']
bkining_proximity_df = biking_dfs['Proximity_df']
# Out:
# Loaded 'Accelerometer.csv' into DataFrame 'Accelerometer_df'. Shape: (90430, 4)
# Loaded 'Linear Accelerometer.csv' into DataFrame 'Linear Accelerometer_df'. Shape: (90430, 4)
# Loaded 'Barometer.csv' into DataFrame 'Barometer_df'. Shape: (847, 2)
# Loaded 'Location.csv' into DataFrame 'Location_df'. Shape: (900, 8)
# Loaded 'Gyroscope.csv' into DataFrame 'Gyroscope_df'. Shape: (90430, 4)
# Loaded 'Magnetometer.csv' into DataFrame 'Magnetometer_df'. Shape: (90430, 4)
# Loaded 'Proximity.csv' into DataFrame 'Proximity_df'. Shape: (66, 2)
#
# Accelerometer_df head:
#    Time (s)  X (m/s^2)  Y (m/s^2)  Z (m/s^2)
# 0  0.008161  -1.333277   8.060289   8.314460
# 1  0.018114  -1.519939   8.037236   6.289621
# 2  0.028068  -1.010099   7.053333   4.551286
# 3  0.038021  -0.723446   6.263126   5.793253
# 4  0.047974  -0.928819   6.392906   6.570437
#
# Gyroscope_df head:
#    Time (s)  X (rad/s)  Y (rad/s)  Z (rad/s)
# 0  0.010650  -0.048301   0.043927   0.077801
# 1  0.020603  -0.013787  -0.115126   0.007624
# 2  0.030556   0.062199  -0.121075   0.037894
# 3  0.040509   0.162161  -0.012193   0.098252
# 4  0.050463   0.264899  -0.085890   0.166806
#
# --- All loaded DataFrames ---
# DataFrame: Accelerometer_df, Columns: ['Time (s)', 'X (m/s^2)', 'Y (m/s^2)', 'Z (m/s^2)'], Shape: (90430, 4)
# DataFrame: Linear Accelerometer_df, Columns: ['Time (s)', 'X (m/s^2)', 'Y (m/s^2)', 'Z (m/s^2)'], Shape: (90430, 4)
# DataFrame: Barometer_df, Columns: ['Time (s)', 'X (hPa)'], Shape: (847, 2)
# DataFrame: Location_df, Columns: ['Time (s)', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Velocity (m/s)', 'Direction (°)', 'Horizontal Accuracy (m)', 'Vertical Accuracy (°)'], Shape: (900, 8)
# DataFrame: Gyroscope_df, Columns: ['Time (s)', 'X (rad/s)', 'Y (rad/s)', 'Z (rad/s)'], Shape: (90430, 4)
# DataFrame: Magnetometer_df, Columns: ['Time (s)', 'X (µT)', 'Y (µT)', 'Z (µT)'], Shape: (90430, 4)
# DataFrame: Proximity_df, Columns: ['Time (s)', 'Distance (cm)'], Shape: (66, 2)

# %%
biking_df = combine_dfs(biking_dfs)
biking_df.head()
# Out:
# Combined DataFrame Head:
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.54                       NaN                       NaN
# 1      0.01                 -1.333277                  8.060289
# 2      0.02                 -1.519939                  8.037236
# 3      0.03                 -1.010099                  7.053333
# 4      0.04                 -0.723446                  6.263126
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                  8.314460                        -0.571053
# 2                  6.289621                        -0.663435
# 3                  4.551286                        -0.093932
# 4                  5.793253                         0.074273
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                         0.853277                         1.423410
# 2                         0.548666                        -0.828132
# 3                        -0.504608                        -1.861800
# 4                        -1.115019                        -0.295147
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0          1006.42868                     NaN                      NaN  ...
# 1                 NaN                     NaN                      NaN  ...
# 2                 NaN                     NaN                      NaN  ...
# 3                 NaN                     NaN                      NaN  ...
# 4                 NaN                     NaN                      NaN  ...
#
#    Location_df_Direction_°  Location_df_Horizontal_Accuracy_m  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#    Location_df_Vertical_Accuracy_°  Gyroscope_df_X_rad/s  \
# 0                              NaN                   NaN
# 1                              NaN             -0.048301
# 2                              NaN             -0.013787
# 3                              NaN              0.062199
# 4                              NaN              0.162161
#
#    Gyroscope_df_Y_rad/s  Gyroscope_df_Z_rad/s  Magnetometer_df_X_µT  \
# 0                   NaN                   NaN                   NaN
# 1              0.043927              0.077801             -3.454794
# 2             -0.115126              0.007624             -3.275377
# 3             -0.121075              0.037894             -3.161579
# 4             -0.012193              0.098252             -3.133875
#
#    Magnetometer_df_Y_µT  Magnetometer_df_Z_µT  Proximity_df_Distance_cm
# 0                   NaN                   NaN                       NaN
# 1            -47.541077            -15.692932                       NaN
# 2            -47.394699            -15.088928                       5.0
# 3            -47.449356            -15.146851                       NaN
# 4            -47.220291            -15.232971                       NaN
#
# [5 rows x 22 columns]
#
# Combined DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93434 entries, 0 to 93433
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Time (s)                           93434 non-null  float64
#  1   Accelerometer_df_X_m/s^2           93433 non-null  float64
#  2   Accelerometer_df_Y_m/s^2           93433 non-null  float64
#  3   Accelerometer_df_Z_m/s^2           93433 non-null  float64
#  4   Linear Accelerometer_df_X_m/s^2    93433 non-null  float64
#  5   Linear Accelerometer_df_Y_m/s^2    93433 non-null  float64
#  6   Linear Accelerometer_df_Z_m/s^2    93433 non-null  float64
#  7   Barometer_df_X_hPa                 874 non-null    float64
#  8   Location_df_Latitude_°             911 non-null    float64
#  9   Location_df_Longitude_°            911 non-null    float64
#  10  Location_df_Height_m               911 non-null    float64
#  11  Location_df_Velocity_m/s           911 non-null    float64
#  12  Location_df_Direction_°            911 non-null    float64
#  13  Location_df_Horizontal_Accuracy_m  911 non-null    float64
#  14  Location_df_Vertical_Accuracy_°    911 non-null    float64
#  15  Gyroscope_df_X_rad/s               93433 non-null  float64
#  16  Gyroscope_df_Y_rad/s               93433 non-null  float64
#  17  Gyroscope_df_Z_rad/s               93433 non-null  float64
#  18  Magnetometer_df_X_µT               93433 non-null  float64
#  19  Magnetometer_df_Y_µT               93433 non-null  float64
#  20  Magnetometer_df_Z_µT               93433 non-null  float64
#  21  Proximity_df_Distance_cm           66 non-null     float64
# dtypes: float64(22)
# memory usage: 15.7 MB
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.54                       NaN                       NaN
# 1      0.01                 -1.333277                  8.060289
# 2      0.02                 -1.519939                  8.037236
# 3      0.03                 -1.010099                  7.053333
# 4      0.04                 -0.723446                  6.263126
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                  8.314460                        -0.571053
# 2                  6.289621                        -0.663435
# 3                  4.551286                        -0.093932
# 4                  5.793253                         0.074273
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                         0.853277                         1.423410
# 2                         0.548666                        -0.828132
# 3                        -0.504608                        -1.861800
# 4                        -1.115019                        -0.295147
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0          1006.42868                     NaN                      NaN  ...
# 1                 NaN                     NaN                      NaN  ...
# 2                 NaN                     NaN                      NaN  ...
# 3                 NaN                     NaN                      NaN  ...
# 4                 NaN                     NaN                      NaN  ...
#
#    Location_df_Direction_°  Location_df_Horizontal_Accuracy_m  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#    Location_df_Vertical_Accuracy_°  Gyroscope_df_X_rad/s  \
# 0                              NaN                   NaN
# 1                              NaN             -0.048301
# 2                              NaN             -0.013787
# 3                              NaN              0.062199
# 4                              NaN              0.162161
#
#    Gyroscope_df_Y_rad/s  Gyroscope_df_Z_rad/s  Magnetometer_df_X_µT  \
# 0                   NaN                   NaN                   NaN
# 1              0.043927              0.077801             -3.454794
# 2             -0.115126              0.007624             -3.275377
# 3             -0.121075              0.037894             -3.161579
# 4             -0.012193              0.098252             -3.133875
#
#    Magnetometer_df_Y_µT  Magnetometer_df_Z_µT  Proximity_df_Distance_cm
# 0                   NaN                   NaN                       NaN
# 1            -47.541077            -15.692932                       NaN
# 2            -47.394699            -15.088928                       5.0
# 3            -47.449356            -15.146851                       NaN
# 4            -47.220291            -15.232971                       NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Walking Data

# %%
# %cd ../
# !ls -F
# Out:
# /content/ml4qs-G39/data/raw
# 'BikingData1 2025-06-06 10-48-07'/  'WalkingData1 2025-06-06 15-30-08'/

# %%
# %cd WalkingData1 2025-06-06 15-30-08
# Out:
# /content/ml4qs-G39/data/raw/WalkingData1 2025-06-06 15-30-08

# %%
# !ls -F
# Out:
#  Accelerometer.csv  'Linear Accelerometer.csv'	 meta/
#  Barometer.csv	     Location.csv		 Proximity.csv
#  Gyroscope.csv	     Magnetometer.csv

# %%
walking_dfs = read_csv_files()
walking_accelerometer_df = walking_dfs['Accelerometer_df']
walking_linear_accelerometer_df = walking_dfs['Linear Accelerometer_df']
walking_barometer_df = walking_dfs['Barometer_df']
walking_location_df = walking_dfs['Location_df']
walking_gyroscope_df = walking_dfs['Gyroscope_df']
walking_magnetometer_df = walking_dfs['Magnetometer_df']
walking_proximity_df = walking_dfs['Proximity_df']
# Out:
# Loaded 'Accelerometer.csv' into DataFrame 'Accelerometer_df'. Shape: (90423, 4)
# Loaded 'Linear Accelerometer.csv' into DataFrame 'Linear Accelerometer_df'. Shape: (90423, 4)
# Loaded 'Barometer.csv' into DataFrame 'Barometer_df'. Shape: (847, 2)
# Loaded 'Location.csv' into DataFrame 'Location_df'. Shape: (899, 8)
# Loaded 'Gyroscope.csv' into DataFrame 'Gyroscope_df'. Shape: (90423, 4)
# Loaded 'Magnetometer.csv' into DataFrame 'Magnetometer_df'. Shape: (90423, 4)
# Loaded 'Proximity.csv' into DataFrame 'Proximity_df'. Shape: (1, 2)
#
# Accelerometer_df head:
#    Time (s)  X (m/s^2)  Y (m/s^2)  Z (m/s^2)
# 0  0.002582  -2.956801   3.204536  12.733271
# 1  0.012535  -1.568887   2.797832  11.682157
# 2  0.022488  -0.466879   3.101850  10.308014
# 3  0.032441  -1.001867   3.238216   8.759784
# 4  0.042394  -1.313219   2.810705   8.288564
#
# Gyroscope_df head:
#    Time (s)  X (rad/s)  Y (rad/s)  Z (rad/s)
# 0  0.000094  -0.010970   0.069035   0.648594
# 1  0.010047   0.057596   0.260039   0.495670
# 2  0.020000  -0.001422   0.377463   0.281415
# 3  0.029953  -0.137912   0.269675   0.173701
# 4  0.039906  -0.327229   0.086331   0.083144
#
# --- All loaded DataFrames ---
# DataFrame: Accelerometer_df, Columns: ['Time (s)', 'X (m/s^2)', 'Y (m/s^2)', 'Z (m/s^2)'], Shape: (90423, 4)
# DataFrame: Linear Accelerometer_df, Columns: ['Time (s)', 'X (m/s^2)', 'Y (m/s^2)', 'Z (m/s^2)'], Shape: (90423, 4)
# DataFrame: Barometer_df, Columns: ['Time (s)', 'X (hPa)'], Shape: (847, 2)
# DataFrame: Location_df, Columns: ['Time (s)', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Velocity (m/s)', 'Direction (°)', 'Horizontal Accuracy (m)', 'Vertical Accuracy (°)'], Shape: (899, 8)
# DataFrame: Gyroscope_df, Columns: ['Time (s)', 'X (rad/s)', 'Y (rad/s)', 'Z (rad/s)'], Shape: (90423, 4)
# DataFrame: Magnetometer_df, Columns: ['Time (s)', 'X (µT)', 'Y (µT)', 'Z (µT)'], Shape: (90423, 4)
# DataFrame: Proximity_df, Columns: ['Time (s)', 'Distance (cm)'], Shape: (1, 2)

# %%
walking_df = combine_dfs(walking_dfs)
walking_df.head()
# Out:
# Combined DataFrame Head:
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.53                       NaN                       NaN
# 1      0.00                 -2.956801                  3.204536
# 2      0.01                 -1.568887                  2.797832
# 3      0.02                 -0.466879                  3.101850
# 4      0.03                 -1.001867                  3.238216
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                 12.733271                        -2.192563
# 2                 11.682157                        -0.712324
# 3                 10.308014                         0.602520
# 4                  8.759784                         0.422396
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                        -0.171700                         4.255854
# 2                        -0.519467                         2.735299
# 3                        -0.465167                         1.634350
# 4                        -0.109258                        -0.077208
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0         1008.348923                     NaN                      NaN  ...
# 1                 NaN                     NaN                      NaN  ...
# 2                 NaN                     NaN                      NaN  ...
# 3                 NaN                     NaN                      NaN  ...
# 4                 NaN                     NaN                      NaN  ...
#
#    Location_df_Direction_°  Location_df_Horizontal_Accuracy_m  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#    Location_df_Vertical_Accuracy_°  Gyroscope_df_X_rad/s  \
# 0                              NaN                   NaN
# 1                              NaN             -0.010970
# 2                              NaN              0.057596
# 3                              NaN             -0.001422
# 4                              NaN             -0.137912
#
#    Gyroscope_df_Y_rad/s  Gyroscope_df_Z_rad/s  Magnetometer_df_X_µT  \
# 0                   NaN                   NaN                   NaN
# 1              0.069035              0.648594            -21.498955
# 2              0.260039              0.495670            -21.380814
# 3              0.377463              0.281415            -21.289383
# 4              0.269675              0.173701            -21.026146
#
#    Magnetometer_df_Y_µT  Magnetometer_df_Z_µT  Proximity_df_Distance_cm
# 0                   NaN                   NaN                       NaN
# 1            -16.158371            -37.334290                       5.0
# 2            -16.132431            -36.897217                       NaN
# 3            -16.068405            -37.185730                       NaN
# 4            -15.975693            -37.676147                       NaN
#
# [5 rows x 22 columns]
#
# Combined DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93378 entries, 0 to 93377
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Time (s)                           93378 non-null  float64
#  1   Accelerometer_df_X_m/s^2           93377 non-null  float64
#  2   Accelerometer_df_Y_m/s^2           93377 non-null  float64
#  3   Accelerometer_df_Z_m/s^2           93377 non-null  float64
#  4   Linear Accelerometer_df_X_m/s^2    93377 non-null  float64
#  5   Linear Accelerometer_df_Y_m/s^2    93377 non-null  float64
#  6   Linear Accelerometer_df_Z_m/s^2    93377 non-null  float64
#  7   Barometer_df_X_hPa                 899 non-null    float64
#  8   Location_df_Latitude_°             939 non-null    float64
#  9   Location_df_Longitude_°            939 non-null    float64
#  10  Location_df_Height_m               939 non-null    float64
#  11  Location_df_Velocity_m/s           938 non-null    float64
#  12  Location_df_Direction_°            934 non-null    float64
#  13  Location_df_Horizontal_Accuracy_m  939 non-null    float64
#  14  Location_df_Vertical_Accuracy_°    939 non-null    float64
#  15  Gyroscope_df_X_rad/s               93377 non-null  float64
#  16  Gyroscope_df_Y_rad/s               93377 non-null  float64
#  17  Gyroscope_df_Z_rad/s               93377 non-null  float64
#  18  Magnetometer_df_X_µT               93377 non-null  float64
#  19  Magnetometer_df_Y_µT               93377 non-null  float64
#  20  Magnetometer_df_Z_µT               93377 non-null  float64
#  21  Proximity_df_Distance_cm           1 non-null      float64
# dtypes: float64(22)
# memory usage: 15.7 MB
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.53                       NaN                       NaN
# 1      0.00                 -2.956801                  3.204536
# 2      0.01                 -1.568887                  2.797832
# 3      0.02                 -0.466879                  3.101850
# 4      0.03                 -1.001867                  3.238216
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                 12.733271                        -2.192563
# 2                 11.682157                        -0.712324
# 3                 10.308014                         0.602520
# 4                  8.759784                         0.422396
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                        -0.171700                         4.255854
# 2                        -0.519467                         2.735299
# 3                        -0.465167                         1.634350
# 4                        -0.109258                        -0.077208
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0         1008.348923                     NaN                      NaN  ...
# 1                 NaN                     NaN                      NaN  ...
# 2                 NaN                     NaN                      NaN  ...
# 3                 NaN                     NaN                      NaN  ...
# 4                 NaN                     NaN                      NaN  ...
#
#    Location_df_Direction_°  Location_df_Horizontal_Accuracy_m  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#    Location_df_Vertical_Accuracy_°  Gyroscope_df_X_rad/s  \
# 0                              NaN                   NaN
# 1                              NaN             -0.010970
# 2                              NaN              0.057596
# 3                              NaN             -0.001422
# 4                              NaN             -0.137912
#
#    Gyroscope_df_Y_rad/s  Gyroscope_df_Z_rad/s  Magnetometer_df_X_µT  \
# 0                   NaN                   NaN                   NaN
# 1              0.069035              0.648594            -21.498955
# 2              0.260039              0.495670            -21.380814
# 3              0.377463              0.281415            -21.289383
# 4              0.269675              0.173701            -21.026146
#
#    Magnetometer_df_Y_µT  Magnetometer_df_Z_µT  Proximity_df_Distance_cm
# 0                   NaN                   NaN                       NaN
# 1            -16.158371            -37.334290                       5.0
# 2            -16.132431            -36.897217                       NaN
# 3            -16.068405            -37.185730                       NaN
# 4            -15.975693            -37.676147                       NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Filling Nulls using interpolaration

# %%
biking_df.isnull().sum()
# Out:
# Time (s)                                 0
# Accelerometer_df_X_m/s^2                 1
# Accelerometer_df_Y_m/s^2                 1
# Accelerometer_df_Z_m/s^2                 1
# Linear Accelerometer_df_X_m/s^2          1
# Linear Accelerometer_df_Y_m/s^2          1
# Linear Accelerometer_df_Z_m/s^2          1
# Barometer_df_X_hPa                   92560
# Location_df_Latitude_°               92523
# Location_df_Longitude_°              92523
# Location_df_Height_m                 92523
# Location_df_Velocity_m/s             92523
# Location_df_Direction_°              92523
# Location_df_Horizontal_Accuracy_m    92523
# Location_df_Vertical_Accuracy_°      92523
# Gyroscope_df_X_rad/s                     1
# Gyroscope_df_Y_rad/s                     1
# Gyroscope_df_Z_rad/s                     1
# Magnetometer_df_X_µT                     1
# Magnetometer_df_Y_µT                     1
# Magnetometer_df_Z_µT                     1
# Proximity_df_Distance_cm             93368
# dtype: int64

# %%
walking_df.isnull().sum()
# Out:
# Time (s)                                 0
# Accelerometer_df_X_m/s^2                 1
# Accelerometer_df_Y_m/s^2                 1
# Accelerometer_df_Z_m/s^2                 1
# Linear Accelerometer_df_X_m/s^2          1
# Linear Accelerometer_df_Y_m/s^2          1
# Linear Accelerometer_df_Z_m/s^2          1
# Barometer_df_X_hPa                   92479
# Location_df_Latitude_°               92439
# Location_df_Longitude_°              92439
# Location_df_Height_m                 92439
# Location_df_Velocity_m/s             92440
# Location_df_Direction_°              92444
# Location_df_Horizontal_Accuracy_m    92439
# Location_df_Vertical_Accuracy_°      92439
# Gyroscope_df_X_rad/s                     1
# Gyroscope_df_Y_rad/s                     1
# Gyroscope_df_Z_rad/s                     1
# Magnetometer_df_X_µT                     1
# Magnetometer_df_Y_µT                     1
# Magnetometer_df_Z_µT                     1
# Proximity_df_Distance_cm             93377
# dtype: int64

# %%
# Interpolate all columns in biking_df
for col in biking_df.columns:
    if biking_df[col].isnull().any():
        biking_df[col].interpolate(method='linear', inplace=True)

# Interpolate all columns in walking_df
for col in walking_df.columns:
    if walking_df[col].isnull().any():
        walking_df[col].interpolate(method='linear', inplace=True)

print("Interpolation complete for biking_df:")
print(biking_df.isnull().sum())

print("\nInterpolation complete for walking_df:")
print(walking_df.isnull().sum())
# Out:
# <ipython-input-21-2452346011>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   biking_df[col].interpolate(method='linear', inplace=True)
# <ipython-input-21-2452346011>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   walking_df[col].interpolate(method='linear', inplace=True)
# Interpolation complete for biking_df:
# Time (s)                              0
# Accelerometer_df_X_m/s^2              1
# Accelerometer_df_Y_m/s^2              1
# Accelerometer_df_Z_m/s^2              1
# Linear Accelerometer_df_X_m/s^2       1
# Linear Accelerometer_df_Y_m/s^2       1
# Linear Accelerometer_df_Z_m/s^2       1
# Barometer_df_X_hPa                    0
# Location_df_Latitude_°               81
# Location_df_Longitude_°              81
# Location_df_Height_m                 81
# Location_df_Velocity_m/s             81
# Location_df_Direction_°              81
# Location_df_Horizontal_Accuracy_m    81
# Location_df_Vertical_Accuracy_°      81
# Gyroscope_df_X_rad/s                  1
# Gyroscope_df_Y_rad/s                  1
# Gyroscope_df_Z_rad/s                  1
# Magnetometer_df_X_µT                  1
# Magnetometer_df_Y_µT                  1
# Magnetometer_df_Z_µT                  1
# Proximity_df_Distance_cm              2
# dtype: int64
#
# Interpolation complete for walking_df:
# Time (s)                               0
# Accelerometer_df_X_m/s^2               1
# Accelerometer_df_Y_m/s^2               1
# Accelerometer_df_Z_m/s^2               1
# Linear Accelerometer_df_X_m/s^2        1
# Linear Accelerometer_df_Y_m/s^2        1
# Linear Accelerometer_df_Z_m/s^2        1
# Barometer_df_X_hPa                     0
# Location_df_Latitude_°                57
# Location_df_Longitude_°               57
# Location_df_Height_m                  57
# Location_df_Velocity_m/s             237
# Location_df_Direction_°              445
# Location_df_Horizontal_Accuracy_m     57
# Location_df_Vertical_Accuracy_°       57
# Gyroscope_df_X_rad/s                   1
# Gyroscope_df_Y_rad/s                   1
# Gyroscope_df_Z_rad/s                   1
# Magnetometer_df_X_µT                   1
# Magnetometer_df_Y_µT                   1
# Magnetometer_df_Z_µT                   1
# Proximity_df_Distance_cm               1
# dtype: int64

# %% [markdown]
# # Analyze Correlation

# %%
print("Biking Data:")
identify_correlation(biking_df)
# Out:
# Biking Data:
# Pairs with Strong Spearman Correlation (absolute value >= 0.6):
#
#   Time (s) vs Location_df_Latitude_°: -0.9995
#   Time (s) vs Location_df_Longitude_°: -0.9851
#   Accelerometer_df_X_m/s^2 vs Linear Accelerometer_df_X_m/s^2: 0.8169
#   Accelerometer_df_Y_m/s^2 vs Linear Accelerometer_df_Y_m/s^2: 0.8133
#   Accelerometer_df_Z_m/s^2 vs Linear Accelerometer_df_Z_m/s^2: 0.8319
#   Location_df_Latitude_° vs Location_df_Longitude_°: 0.9845

# %%
print("Walking Data:")
identify_correlation(walking_df)
# Out:
# Walking Data:
# Pairs with Strong Spearman Correlation (absolute value >= 0.6):
#
#   Time (s) vs Location_df_Latitude_°: -0.9995
#   Time (s) vs Location_df_Longitude_°: -0.9851
#   Accelerometer_df_X_m/s^2 vs Linear Accelerometer_df_X_m/s^2: 0.8169
#   Accelerometer_df_Y_m/s^2 vs Linear Accelerometer_df_Y_m/s^2: 0.8133
#   Accelerometer_df_Z_m/s^2 vs Linear Accelerometer_df_Z_m/s^2: 0.8319
#   Location_df_Latitude_° vs Location_df_Longitude_°: 0.9845

# %%
biking_df.columns
# Out:
# Index(['Time (s)', 'Accelerometer_df_X_m/s^2', 'Accelerometer_df_Y_m/s^2',
#        'Accelerometer_df_Z_m/s^2', 'Linear Accelerometer_df_X_m/s^2',
#        'Linear Accelerometer_df_Y_m/s^2', 'Linear Accelerometer_df_Z_m/s^2',
#        'Barometer_df_X_hPa', 'Location_df_Latitude_°',
#        'Location_df_Longitude_°', 'Location_df_Height_m',
#        'Location_df_Velocity_m/s', 'Location_df_Direction_°',
#        'Location_df_Horizontal_Accuracy_m', 'Location_df_Vertical_Accuracy_°',
#        'Gyroscope_df_X_rad/s', 'Gyroscope_df_Y_rad/s', 'Gyroscope_df_Z_rad/s',
#        'Magnetometer_df_X_µT', 'Magnetometer_df_Y_µT', 'Magnetometer_df_Z_µT',
#        'Proximity_df_Distance_cm'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Time Based

# %%
## TODO using meta data (in meta folder) calculate time of day

# %% [markdown]
# ## Linear Acceleration

# %%
def calculate_linear_acceleration_magnitude(df):
  # Total Linear Acceleration Magnitude
  df['linear_acceleration_magnitude_m/s^2'] = np.sqrt(
      df['Linear Accelerometer_df_X_m/s^2']**2 +
      df['Linear Accelerometer_df_Y_m/s^2']**2 +
      df['Linear Accelerometer_df_Z_m/s^2']**2
  )
  return df

# Biking df
biking_df = calculate_linear_acceleration_magnitude(biking_df)

# Walking df
walking_df = calculate_linear_acceleration_magnitude(walking_df)
walking_df.head()
# Out:
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.53                       NaN                       NaN
# 1      0.00                 -2.956801                  3.204536
# 2      0.01                 -1.568887                  2.797832
# 3      0.02                 -0.466879                  3.101850
# 4      0.03                 -1.001867                  3.238216
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                 12.733271                        -2.192563
# 2                 11.682157                        -0.712324
# 3                 10.308014                         0.602520
# 4                  8.759784                         0.422396
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                        -0.171700                         4.255854
# 2                        -0.519467                         2.735299
# 3                        -0.465167                         1.634350
# 4                        -0.109258                        -0.077208
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0         1008.348923                     NaN                      NaN  ...
# 1         1008.348929                     NaN                      NaN  ...
# 2         1008.348935                     NaN                      NaN  ...
# 3         1008.348941                     NaN                      NaN  ...
# 4         1008.348947                     NaN                      NaN  ...
#
#    Location_df_Horizontal_Accuracy_m  Location_df_Vertical_Accuracy_°  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    Gyroscope_df_X_rad/s  Gyroscope_df_Y_rad/s  Gyroscope_df_Z_rad/s  \
# 0                   NaN                   NaN                   NaN
# 1             -0.010970              0.069035              0.648594
# 2              0.057596              0.260039              0.495670
# 3             -0.001422              0.377463              0.281415
# 4             -0.137912              0.269675              0.173701
#
#    Magnetometer_df_X_µT  Magnetometer_df_Y_µT  Magnetometer_df_Z_µT  \
# 0                   NaN                   NaN                   NaN
# 1            -21.498955            -16.158371            -37.334290
# 2            -21.380814            -16.132431            -36.897217
# 3            -21.289383            -16.068405            -37.185730
# 4            -21.026146            -15.975693            -37.676147
#
#    Proximity_df_Distance_cm  linear_acceleration_magnitude_m/s^2
# 0                       NaN                                  NaN
# 1                       5.0                             4.790523
# 2                       5.0                             2.873867
# 3                       5.0                             1.802917
# 4                       5.0                             0.443077
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Turning Rate / Change in Direction

# %%
def calculate_turning_rate(df):
  # Turning Rate / Change in Direction
  # Handle circular nature of degrees (0-360)
  df['direction_diff_deg'] = df['Location_df_Direction_°'].diff().apply(
      lambda x: (x + 180) % 360 - 180 if pd.notna(x) else x
  )
  df['dt_s'] = df['Time (s)'].diff()
  df['turning_rate_deg/s'] = df['direction_diff_deg'] / df['dt_s']
  df['absolute_turning_rate_deg/s'] = df['turning_rate_deg/s'].abs()
  return df

# Biking df
biking_df = calculate_turning_rate(biking_df)

# Walking df
walking_df = calculate_turning_rate(walking_df)
walking_df.head()
# Out:
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.53                       NaN                       NaN
# 1      0.00                 -2.956801                  3.204536
# 2      0.01                 -1.568887                  2.797832
# 3      0.02                 -0.466879                  3.101850
# 4      0.03                 -1.001867                  3.238216
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                 12.733271                        -2.192563
# 2                 11.682157                        -0.712324
# 3                 10.308014                         0.602520
# 4                  8.759784                         0.422396
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                        -0.171700                         4.255854
# 2                        -0.519467                         2.735299
# 3                        -0.465167                         1.634350
# 4                        -0.109258                        -0.077208
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0         1008.348923                     NaN                      NaN  ...
# 1         1008.348929                     NaN                      NaN  ...
# 2         1008.348935                     NaN                      NaN  ...
# 3         1008.348941                     NaN                      NaN  ...
# 4         1008.348947                     NaN                      NaN  ...
#
#    Gyroscope_df_Z_rad/s  Magnetometer_df_X_µT  Magnetometer_df_Y_µT  \
# 0                   NaN                   NaN                   NaN
# 1              0.648594            -21.498955            -16.158371
# 2              0.495670            -21.380814            -16.132431
# 3              0.281415            -21.289383            -16.068405
# 4              0.173701            -21.026146            -15.975693
#
#    Magnetometer_df_Z_µT  Proximity_df_Distance_cm  \
# 0                   NaN                       NaN
# 1            -37.334290                       5.0
# 2            -36.897217                       5.0
# 3            -37.185730                       5.0
# 4            -37.676147                       5.0
#
#    linear_acceleration_magnitude_m/s^2  direction_diff_deg  dt_s  \
# 0                                  NaN                 NaN   NaN
# 1                             4.790523                 NaN  0.53
# 2                             2.873867                 NaN  0.01
# 3                             1.802917                 NaN  0.01
# 4                             0.443077                 NaN  0.01
#
#    turning_rate_deg/s  absolute_turning_rate_deg/s
# 0                 NaN                          NaN
# 1                 NaN                          NaN
# 2                 NaN                          NaN
# 3                 NaN                          NaN
# 4                 NaN                          NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Acceleration from GPS

# %%
def calculate_gps_acceleration(df):
  # Acceleration from GPS
  df['gps_acceleration_m/s^2'] = df['Location_df_Velocity_m/s'].diff() / df['dt_s']
  return df

# Biking df
biking_df = calculate_gps_acceleration(biking_df)

# Walking df
walking_df = calculate_gps_acceleration(walking_df)
walking_df.head()
# Out:
#    Time (s)  Accelerometer_df_X_m/s^2  Accelerometer_df_Y_m/s^2  \
# 0     -0.53                       NaN                       NaN
# 1      0.00                 -2.956801                  3.204536
# 2      0.01                 -1.568887                  2.797832
# 3      0.02                 -0.466879                  3.101850
# 4      0.03                 -1.001867                  3.238216
#
#    Accelerometer_df_Z_m/s^2  Linear Accelerometer_df_X_m/s^2  \
# 0                       NaN                              NaN
# 1                 12.733271                        -2.192563
# 2                 11.682157                        -0.712324
# 3                 10.308014                         0.602520
# 4                  8.759784                         0.422396
#
#    Linear Accelerometer_df_Y_m/s^2  Linear Accelerometer_df_Z_m/s^2  \
# 0                              NaN                              NaN
# 1                        -0.171700                         4.255854
# 2                        -0.519467                         2.735299
# 3                        -0.465167                         1.634350
# 4                        -0.109258                        -0.077208
#
#    Barometer_df_X_hPa  Location_df_Latitude_°  Location_df_Longitude_°  ...  \
# 0         1008.348923                     NaN                      NaN  ...
# 1         1008.348929                     NaN                      NaN  ...
# 2         1008.348935                     NaN                      NaN  ...
# 3         1008.348941                     NaN                      NaN  ...
# 4         1008.348947                     NaN                      NaN  ...
#
#    Magnetometer_df_X_µT  Magnetometer_df_Y_µT  Magnetometer_df_Z_µT  \
# 0                   NaN                   NaN                   NaN
# 1            -21.498955            -16.158371            -37.334290
# 2            -21.380814            -16.132431            -36.897217
# 3            -21.289383            -16.068405            -37.185730
# 4            -21.026146            -15.975693            -37.676147
#
#    Proximity_df_Distance_cm  linear_acceleration_magnitude_m/s^2  \
# 0                       NaN                                  NaN
# 1                       5.0                             4.790523
# 2                       5.0                             2.873867
# 3                       5.0                             1.802917
# 4                       5.0                             0.443077
#
#    direction_diff_deg  dt_s  turning_rate_deg/s  absolute_turning_rate_deg/s  \
# 0                 NaN   NaN                 NaN                          NaN
# 1                 NaN  0.53                 NaN                          NaN
# 2                 NaN  0.01                 NaN                          NaN
# 3                 NaN  0.01                 NaN                          NaN
# 4                 NaN  0.01                 NaN                          NaN
#
#    gps_acceleration_m/s^2
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 28 columns]
